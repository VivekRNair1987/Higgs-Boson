# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
pd. __version__
# Out:
# '1.0.5'

# %%
hboson_dataset  =pd.read_csv("training.csv")

# %%
## Reading the first 5 rows of the dataset

hboson_dataset.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_num  PRI_jet_leading_pt  \
# ...

# %%
## Reading the last 10 rows of the dataset

hboson_dataset.tail(10)
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 249990   349990       127.822                       82.865       100.024
# 249991   349991       133.457                       77.540        88.989
# 249992   349992      -999.000                       38.083       749.970
# 249993   349993       130.075                        3.918        66.781
# 249994   349994       217.020                       47.156        62.824
# 249995   349995      -999.000                       71.989        36.548
# 249996   349996      -999.000                       58.179        68.083
# 249997   349997       105.457                       60.526        75.839
# 249998   349998        94.951                       19.362        68.812
# 249999   349999      -999.000                       72.756        70.831
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 249990     0.860              -999.000          -999.000             -999.000
# ...

# %%
hboson_dataset.replace(-999,np.nan, inplace=True)

# %%
## Finding out the rows and columns of the dataset

print("The dataset contains {} rows and {} columns".format(hboson_dataset.shape[0],hboson_dataset.shape[1]))
# Out:
# The dataset contains 250000 rows and 33 columns

# %%
## Dataset Information

hboson_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      250000 non-null  int64
#  1   DER_mass_MMC                 211886 non-null  float64
#  2   DER_mass_transverse_met_lep  250000 non-null  float64
#  3   DER_mass_vis                 250000 non-null  float64
#  4   DER_pt_h                     250000 non-null  float64
#  5   DER_deltaeta_jet_jet         72543 non-null   float64
#  6   DER_mass_jet_jet             72543 non-null   float64
#  7   DER_prodeta_jet_jet          72543 non-null   float64
#  8   DER_deltar_tau_lep           250000 non-null  float64
#  9   DER_pt_tot                   250000 non-null  float64
#  10  DER_sum_pt                   250000 non-null  float64
#  11  DER_pt_ratio_lep_tau         250000 non-null  float64
# ...

# %%
## Checking the statistical measures of the features

hboson_dataset.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  211886.000000                250000.000000
# mean   224999.500000     121.858528                    49.239819
# std     72168.927986      57.298157                    35.344886
# min    100000.000000       9.044000                     0.000000
# 25%    162499.750000      91.885250                    19.241000
# 50%    224999.500000     112.406000                    46.524000
# 75%    287499.250000     135.482000                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000          72543.000000      72543.000000
# mean       81.181982      57.895962              2.403735        371.783360
# std        40.828691      63.655682              1.742226        397.699325
# ...

# %%
## Checking the null values of the dataset


hboson_dataset.isna().sum()
# Out:
# EventId                             0
# DER_mass_MMC                    38114
# DER_mass_transverse_met_lep         0
# DER_mass_vis                        0
# DER_pt_h                            0
# DER_deltaeta_jet_jet           177457
# DER_mass_jet_jet               177457
# DER_prodeta_jet_jet            177457
# DER_deltar_tau_lep                  0
# DER_pt_tot                          0
# DER_sum_pt                          0
# DER_pt_ratio_lep_tau                0
# DER_met_phi_centrality              0
# DER_lep_eta_centrality         177457
# PRI_tau_pt                          0
# PRI_tau_eta                         0
# PRI_tau_phi                         0
# PRI_lep_pt                          0
# PRI_lep_eta                         0
# PRI_lep_phi                         0
# PRI_met                             0
# PRI_met_phi                         0
# PRI_met_sumet                       0
# PRI_jet_num                         0
# PRI_jet_leading_pt              99913
# ...

# %% [markdown]
# There are multiple null values in the dataset

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in hboson_dataset.columns if hboson_dataset[features].isnull().sum()>0]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(hboson_dataset[feature].isnull().mean()*100, 2),  ' % missing values')
# Out:
# DER_mass_MMC 15.25  % missing values
# DER_deltaeta_jet_jet 70.98  % missing values
# DER_mass_jet_jet 70.98  % missing values
# DER_prodeta_jet_jet 70.98  % missing values
# DER_lep_eta_centrality 70.98  % missing values
# PRI_jet_leading_pt 39.97  % missing values
# PRI_jet_leading_eta 39.97  % missing values
# PRI_jet_leading_phi 39.97  % missing values
# PRI_jet_subleading_pt 70.98  % missing values
# PRI_jet_subleading_eta 70.98  % missing values
# PRI_jet_subleading_phi 70.98  % missing values

# %%
columns = ["DER_deltaeta_jet_jet","DER_mass_jet_jet","DER_prodeta_jet_jet","DER_lep_eta_centrality","PRI_jet_subleading_pt","PRI_jet_subleading_eta","PRI_jet_subleading_phi"]
hboson_dataset.drop(columns=columns, inplace= True, axis=1)

# %%
median_DER_mass_MMC = hboson_dataset["DER_mass_MMC"].median()
hboson_dataset["DER_mass_MMC"].fillna(median_DER_mass_MMC,inplace=True)
hboson_dataset["DER_mass_MMC"].isna().sum()
# Out:
# 0

# %%
median_PRI_jet_leading_pt = hboson_dataset["PRI_jet_leading_pt"].median()
hboson_dataset["PRI_jet_leading_pt"].fillna(median_PRI_jet_leading_pt,inplace=True)
hboson_dataset["PRI_jet_leading_pt"].isna().sum()
# Out:
# 0

# %%
median_PRI_jet_leading_eta = hboson_dataset["PRI_jet_leading_eta"].median()
hboson_dataset["PRI_jet_leading_eta"].fillna(median_PRI_jet_leading_eta,inplace=True)
hboson_dataset["PRI_jet_leading_eta"].isna().sum()
# Out:
# 0

# %%
median_PRI_jet_leading_phi = hboson_dataset["PRI_jet_leading_phi"].median()
hboson_dataset["PRI_jet_leading_phi"].fillna(median_PRI_jet_leading_phi,inplace=True)
hboson_dataset["PRI_jet_leading_phi"].isna().sum()
# Out:
# 0

# %%
hboson_dataset.isna().sum()
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_all_pt                 0
# Weight                         0
# Label                          0
# dtype: int64

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# ### Univariate Analysis

# %%
hboson_dataset.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltar_tau_lep', 'DER_pt_tot',
#        'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
hboson_dataset.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     120.417434                    49.239819
# std     72168.927986      52.859218                    35.344886
# min    100000.000000       9.044000                     0.000000
# 25%    162499.750000      95.665000                    19.241000
# 50%    224999.500000     112.406000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltar_tau_lep     DER_pt_tot  \
# count  250000.000000  250000.000000       250000.000000  250000.000000
# mean       81.181982      57.895962            2.373100      18.917332
# std        40.828691      63.655682            0.782911      22.273494
# min         6.329000       0.000000            0.208000       0.000000
# ...

# %%
## Distribution of DER_mass_MMC

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_mass_MMC"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_mass_transverse_met_lep

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_mass_transverse_met_lep"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_mass_vis

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_mass_vis"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_pt_h

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_pt_h"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_deltar_tau_lep

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_deltar_tau_lep"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of 'DER_pt_tot'

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_pt_tot"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_sum_pt

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_sum_pt"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_pt_ratio_lep_tau

figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_pt_ratio_lep_tau"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of DER_met_phi_centrality


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["DER_met_phi_centrality"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_tau_pt


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_tau_pt"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_tau_eta


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_tau_eta"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_tau_phi


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_tau_phi"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_lep_pt


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_lep_pt"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_lep_eta


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_lep_eta"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_lep_phi


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_lep_phi"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_met_phi


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_met_phi"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_met_sumet


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_met_sumet"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_jet_num


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_jet_num"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_jet_leading_pt


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_jet_leading_pt"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_jet_leading_eta


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_jet_leading_eta"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_jet_leading_phi


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_jet_leading_phi"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of PRI_jet_all_pt


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["PRI_jet_all_pt"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
## Distribution of Weight


figs = plt.figure(figsize=(12,7))
sub1 = figs.add_subplot(121)
sub2 = figs.add_subplot(122)
x = hboson_dataset["Weight"]
sub1.hist(x)
sub2.boxplot(x)
plt.show()

# %%
hboson_dataset.Label.value_counts()
# Out:
# b    164333
# s     85667
# Name: Label, dtype: int64

# %%
## Distribution of Label


plt.figure(figsize=(10,10))
sns.countplot(hboson_dataset["Label"])
plt.title("Label Distribution")
plt.show()

# %%
hboson_dataset.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltar_tau_lep', 'DER_pt_tot',
#        'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
data=hboson_dataset

# %%
data.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltar_tau_lep', 'DER_pt_tot',
#        'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
data.shape
# Out:
# (250000, 26)

# %%
data.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     120.417434                    49.239819
# std     72168.927986      52.859218                    35.344886
# min    100000.000000       9.044000                     0.000000
# 25%    162499.750000      95.665000                    19.241000
# 50%    224999.500000     112.406000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltar_tau_lep     DER_pt_tot  \
# count  250000.000000  250000.000000       250000.000000  250000.000000
# mean       81.181982      57.895962            2.373100      18.917332
# std        40.828691      63.655682            0.782911      22.273494
# min         6.329000       0.000000            0.208000       0.000000
# ...

# %%
q = data['DER_mass_MMC'].quantile(0.96)
data_cleaned = data[data['DER_mass_MMC']<q]
q = data_cleaned['DER_mass_transverse_met_lep'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_mass_transverse_met_lep']<q]
q = data_cleaned['DER_mass_vis'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_mass_vis']<q]
q = data_cleaned['DER_pt_h'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_pt_h']<q]
q = data_cleaned['DER_sum_pt'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_sum_pt']<q]
q = data_cleaned['DER_pt_ratio_lep_tau'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_pt_ratio_lep_tau']<q]
q = data_cleaned['PRI_tau_pt'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['PRI_tau_pt']<q]
q = data_cleaned['DER_pt_ratio_lep_tau'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['DER_pt_ratio_lep_tau']<q]
q = data_cleaned['PRI_lep_pt'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['PRI_lep_pt']<q]
q = data_cleaned['PRI_met_sumet'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['PRI_met_sumet']<q]
q = data_cleaned['PRI_jet_leading_pt'].quantile(0.96)
data_cleaned  = data_cleaned[data_cleaned['PRI_jet_leading_pt']<q]
q = data_cleaned['PRI_jet_all_pt'].quantile(0.95)
data_cleaned  = data_cleaned[data_cleaned['PRI_jet_all_pt']<q]

# %%
data_cleaned.shape
# Out:
# (151556, 26)

# %%
new_hboson_df_us = data_cleaned

# %%
new_hboson_df_us.head()
# Out:
#     EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0    100000       138.470                       51.655        97.827
# 1    100001       160.937                       68.768       103.235
# 8    100008       105.594                       50.559       100.989
# 10   100010       112.406                       86.240        79.692
# 12   100012       145.297                       64.234       103.565
#
#     DER_pt_h  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  \
# 0     27.980               3.064      41.928     197.760
# 1     48.146               3.473       2.078     125.157
# 8      4.288               2.904       4.288      65.333
# 10    27.201               2.338      27.201      81.734
# 12   106.999               2.183      24.660     192.245
#
#     DER_pt_ratio_lep_tau  DER_met_phi_centrality  ...  PRI_met  PRI_met_phi  \
# 0                  1.582                   1.396  ...   16.824       -0.277
# ...

# %%
new_hboson_df_us.shape
# Out:
# (151556, 26)

# %%
new_hboson_df_us.Label.value_counts()
# Out:
# b    100375
# s     51181
# Name: Label, dtype: int64

# %%
## Finding the correlation of all the features in the dataset

new_hboson_df_us.corr()
# Out:
#                               EventId  DER_mass_MMC  \
# EventId                      1.000000      0.003588
# DER_mass_MMC                 0.003588      1.000000
# DER_mass_transverse_met_lep -0.006142     -0.014053
# DER_mass_vis                 0.001784      0.686081
# DER_pt_h                     0.002169      0.016868
# DER_deltar_tau_lep           0.002000      0.437484
# DER_pt_tot                   0.005087     -0.027820
# DER_sum_pt                   0.002093      0.178821
# DER_pt_ratio_lep_tau        -0.005027     -0.140280
# DER_met_phi_centrality       0.003454      0.095124
# PRI_tau_pt                   0.003406      0.395256
# PRI_tau_eta                  0.000085      0.003315
# PRI_tau_phi                 -0.000444     -0.003727
# PRI_lep_pt                  -0.001790      0.267178
# PRI_lep_eta                  0.001983      0.000672
# PRI_lep_phi                 -0.001855      0.000477
# PRI_met                     -0.000457      0.137936
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(new_hboson_df_us.corr(),cmap=plt.cm.CMRmap_r, annot = True,linewidths=2,linecolor="black")
plt.title('Correlation Matrix',fontsize=40)
plt.show()

# %%
columns = ["EventId","PRI_jet_num","DER_sum_pt","DER_pt_h","DER_pt_ratio_lep_tau"]

# %%
new_hboson_df_us.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltar_tau_lep', 'DER_pt_tot',
#        'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
new_hboson_df_us.drop(columns, inplace=True, axis=1)

# %%
new_hboson_df_us.columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
## Importing necessary Libraries for Modeling

from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %% [markdown]
# ##### Converting the dependent feature to an integer format

# %%
data = new_hboson_df_us

# %%
data["Label"].unique()
# Out:
# array(['s', 'b'], dtype=object)

# %%
data["Label"] = data["Label"].str.replace('b',"0")
data["Label"] = data["Label"].str.replace('s',"1")

# %%
data["Label"] = data["Label"].astype(int)

# %%
data["Label"].unique()
# Out:
# array([1, 0])

# %%
X = data.drop(columns = ['Label'])
y = data['Label']

# %%
y
# Out:
# 0         1
# 1         0
# 8         0
# 10        0
# 12        0
#          ..
# 249995    0
# 249996    0
# 249997    1
# 249998    0
# 249999    0
# Name: Label, Length: 151556, dtype: int32

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=32 :
        ax = plt.subplot(8,4,plotnumber)
        sns.stripplot(y,X[column])
    plotnumber+=1
plt.tight_layout()

# %%
## Normalising the data

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
## Checking for multicollinearity

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["Features"] = X.columns

#let's check the values
vif
# Out:
#          vif                     Features
# 0   2.550586                 DER_mass_MMC
# 1   2.533175  DER_mass_transverse_met_lep
# 2   6.167166                 DER_mass_vis
# 3   3.899985           DER_deltar_tau_lep
# 4   1.328424                   DER_pt_tot
# 5   1.719790       DER_met_phi_centrality
# 6   2.579335                   PRI_tau_pt
# 7   1.770626                  PRI_tau_eta
# 8   1.124134                  PRI_tau_phi
# 9   1.795951                   PRI_lep_pt
# 10  1.769657                  PRI_lep_eta
# 11  1.147599                  PRI_lep_phi
# 12  2.249479                      PRI_met
# 13  1.064978                  PRI_met_phi
# 14  2.262235                PRI_met_sumet
# 15  1.057116           PRI_jet_leading_pt
# 16  1.033932          PRI_jet_leading_eta
# 17  1.114516          PRI_jet_leading_phi
# 18  2.545064               PRI_jet_all_pt
# 19  1.945870                       Weight

# %%
## Performing a Train- Test Split

X_train,X_test,y_train,y_test = train_test_split(X_scaled,y, test_size= 0.30, random_state = 355)

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = LogisticRegression()

log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9834825257879342

# %%
# Confusion Matrix
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[29444,   709],
#        [   42, 15272]], dtype=int64)

# %%
log_reg.score(X_train,y_train)
# Out:
# 0.9855121643148677

# %%
log_reg.score(X_test,y_test)
# Out:
# 0.9834825257879342

# %%
true_positive = conf_mat[0][0]
false_positive = conf_mat[0][1]
false_negative = conf_mat[1][0]
true_negative = conf_mat[1][1]

# %%
# Breaking down the formula for Accuracy
Accuracy = (true_positive + true_negative) / (true_positive +false_positive + false_negative + true_negative)
Accuracy
# Out:
# 0.9834825257879342

# %%
# Precison
Precision = true_positive/(true_positive+false_positive)
Precision
# Out:
# 0.9764865850827447

# %%
# Recall
Recall = true_positive/(true_positive+false_negative)
Recall
# Out:
# 0.998575595197721

# %%
# F1 Score
F1_Score = 2*(Recall * Precision) / (Recall + Precision)
F1_Score
# Out:
# 0.9874075688727175

# %%
# Area Under Curve
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.9868719983008082

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.model_selection import GridSearchCV
import pydotplus

# %%
#let's first visualize the tree on the data without doing any pre processing
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_train,y_train)
# Out:
# 1.0

# %%
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter' : ['best', 'random']
    
}

# %%
grid_search = GridSearchCV(estimator=clf,
                     param_grid=grid_param,
                     cv=5,
                    n_jobs =-1)

# %%
grid_search.fit(X_train,y_train)

# %%
best_parameters = grid_search.best_params_
print(best_parameters)

# %%
grid_search.best_score_

# %%
clf = DecisionTreeClassifier(criterion = 'gini', max_depth =2, min_samples_leaf= 1, min_samples_split= 2, splitter ='best')
clf.fit(X_train,y_train)

# %%
clf.score(X_train,y_train)

# %%
clf.score(X_test,y_test)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_test = model.predict(X_test)

# %%
y_pred_train = model.predict(X_train)

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 1.0

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 1.0

# %% [markdown]
# ## Save Model

# %%
import joblib

# %%
with open("./final_bestmodel11.joblib", 'wb') as x:
    joblib.dump(clf, x, compress=3)

# %%
X.columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_met_phi_centrality',
#        'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta',
#        'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_all_pt', 'Weight'],
#       dtype='object')
